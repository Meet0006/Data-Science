# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image

# %%
train_path= 'C:/Users/meetp/Downloads/Covid19-dataset/train'
test_path= 'C:/Users/meetp/Downloads/Covid19-dataset/test'

# %%
train_data= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_data= image.ImageDataGenerator(    
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_data.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 4,
    class_mode = 'categorical')
validation_generator = test_data.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 4,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %%
base_model = tf.keras.applications.EfficientNetB3(weights='imagenet', input_shape=(224,224,3), include_top=False)

for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)          │ ?                           │      10,783,535 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │     0 (unbuilt) │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise_1 (GaussianNoise)     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,783,535 (41.14 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 10,783,535 (41.14 MB)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

lrp = ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=2)
filepath = 'best_model.keras'  # Change filepath extension to .keras
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks = [checkpoint, lrp]

history = model.fit(
    train_generator,
    epochs=5,
    validation_data=validation_generator,
    steps_per_epoch=5,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# D:\Pycharm_Projects\Data_Science_Internship\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - AUC: 0.3168 - Precision: 0.1850 - Recall: 0.1850 - accuracy: 0.1850 - loss: 2.6717
# Epoch 1: val_accuracy improved from -inf to 0.59091, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - AUC: 0.3475 - Precision: 0.2042 - Recall: 0.2042 - accuracy: 0.2042 - loss: 2.5802 - val_AUC: 0.7871 - val_Precision: 0.6327 - val_Recall: 0.4697 - val_accuracy: 0.5909 - val_loss: 0.8454 - learning_rate: 0.0010
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - AUC: 0.8735 - Precision: 0.7533 - Recall: 0.7533 - accuracy: 0.7533 - loss: 0.8484
# Epoch 2: val_accuracy improved from 0.59091 to 0.65152, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - AUC: 0.8644 - Precision: 0.7278 - Recall: 0.7278 - accuracy: 0.7278 - loss: 0.8973 - val_AUC: 0.8632 - val_Precision: 0.6964 - val_Recall: 0.5909 - val_accuracy: 0.6515 - val_loss: 0.6804 - learning_rate: 0.0010
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - AUC: 0.8367 - Precision: 0.5783 - Recall: 0.5783 - accuracy: 0.5783 - loss: 1.1676
# Epoch 3: val_accuracy improved from 0.65152 to 0.71212, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - AUC: 0.8321 - Precision: 0.5819 - Recall: 0.5819 - accuracy: 0.5819 - loss: 1.2154 - val_AUC: 0.8887 - val_Precision: 0.7193 - val_Recall: 0.6212 - val_accuracy: 0.7121 - val_loss: 0.6449 - learning_rate: 0.0010
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - AUC: 0.9573 - Precision: 0.7992 - Recall: 0.7992 - accuracy: 0.7992 - loss: 0.4134
# Epoch 4: val_accuracy did not improve from 0.71212
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - AUC: 0.9590 - Precision: 0.8076 - Recall: 0.8076 - accuracy: 0.8076 - loss: 0.4059 - val_AUC: 0.8845 - val_Precision: 0.7000 - val_Recall: 0.6364 - val_accuracy: 0.6667 - val_loss: 0.6674 - learning_rate: 0.0010
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - AUC: 0.9271 - Precision: 0.8042 - Recall: 0.8042 - accuracy: 0.8042 - loss: 0.6186
# Epoch 5: val_accuracy did not improve from 0.71212
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - AUC: 0.9183 - Precision: 0.7951 - Recall: 0.7951 - accuracy: 0.7951 - loss: 0.6740 - val_AUC: 0.8937 - val_Precision: 0.7288 - val_Recall: 0.6515 - val_accuracy: 0.6818 - val_loss: 0.6232 - learning_rate: 0.0010

# %%
model.evaluate(train_generator)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 529ms/step - AUC: 0.9008 - Precision: 0.7763 - Recall: 0.7029 - accuracy: 0.7229 - loss: 0.6034
# [0.5488548278808594,
#  0.9193187952041626,
#  0.7878788113594055,
#  0.7250996232032776,
#  0.7529880404472351]

# %%
model.evaluate(validation_generator)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - AUC: 0.8728 - Precision: 0.6829 - Recall: 0.6266 - accuracy: 0.6544 - loss: 0.6639
# [0.6846134662628174,
#  0.8665059208869934,
#  0.6666666865348816,
#  0.6363636255264282,
#  0.6515151262283325]

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img("C:/Users/meetp/Downloads/covid/co3.jpg",target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
# a=ypred[0]

# if a<=0.0302958:
#       op="Covid"   
# elif a<=0.96526605:
#       op="Normal"
# else:
#       op="Viral Enfection"
res = np.argmax(ypred[0])
if res == 0:
    print('Covid')
elif res == 1:
    print('Normal')
else:
    print('Viral Pneumonia')
    
plt.imshow(img)
# print("THE UPLOADED X-RAY IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# [[0.659275   0.33181062 0.00891432]]
# Covid
