# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image

# %%
train_path= 'D:/Download/Plant Diseases Dataset/train'
test_path= 'D:/Download/Plant Diseases Dataset/test'

# %%
train_data= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_data= image.ImageDataGenerator(    
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_data.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 4,
    class_mode = 'binary')
validation_generator = test_data.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 4,
    shuffle=True,
    class_mode = 'binary')
# Out:
# Found 70295 images belonging to 2 classes.
# Found 17572 images belonging to 2 classes.

# %%
base_model = tf.keras.applications.EfficientNetB3(weights='imagenet', input_shape=(224,224,3), include_top=False)

for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)          │ ?                           │      10,783,535 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │     0 (unbuilt) │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise_1 (GaussianNoise)     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,783,535 (41.14 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 10,783,535 (41.14 MB)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

lrp = ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=2)
filepath = 'best_model.keras'  # Change filepath extension to .keras
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks = [checkpoint, lrp]

history = model.fit(
    train_generator,
    epochs=12,
    validation_data=validation_generator,
    steps_per_epoch=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/12
# D:\Pycharm_Projects\Data_Science_Internship\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - AUC: 0.6166 - Precision: 0.6853 - Recall: 0.6017 - accuracy: 0.5713 - loss: 0.8701
# Epoch 1: val_accuracy improved from -inf to 0.66657, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1731s 58s/step - AUC: 0.6174 - Precision: 0.6879 - Recall: 0.6020 - accuracy: 0.5727 - loss: 0.8720 - val_AUC: 0.8423 - val_Precision: 0.9053 - val_Recall: 0.5715 - val_accuracy: 0.6666 - val_loss: 0.5888 - learning_rate: 0.0010
# Epoch 2/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - AUC: 0.6728 - Precision: 0.8156 - Recall: 0.6130 - accuracy: 0.6180 - loss: 0.9148
# Epoch 2: val_accuracy improved from 0.66657 to 0.80736, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1328s 46s/step - AUC: 0.6739 - Precision: 0.8149 - Recall: 0.6140 - accuracy: 0.6185 - loss: 0.9126 - val_AUC: 0.8434 - val_Precision: 0.8419 - val_Recall: 0.8839 - val_accuracy: 0.8074 - val_loss: 0.4481 - learning_rate: 0.0010
# Epoch 3/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - AUC: 0.8298 - Precision: 0.9022 - Recall: 0.6686 - accuracy: 0.6666 - loss: 0.6501
# Epoch 3: val_accuracy improved from 0.80736 to 0.81249, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1326s 46s/step - AUC: 0.8268 - Precision: 0.9001 - Recall: 0.6692 - accuracy: 0.6666 - loss: 0.6515 - val_AUC: 0.8848 - val_Precision: 0.8846 - val_Recall: 0.8342 - val_accuracy: 0.8125 - val_loss: 0.4260 - learning_rate: 0.0010
# Epoch 4/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - AUC: 0.8026 - Precision: 0.8322 - Recall: 0.7524 - accuracy: 0.7341 - loss: 0.5683
# Epoch 4: val_accuracy improved from 0.81249 to 0.81476, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1585s 55s/step - AUC: 0.8023 - Precision: 0.8326 - Recall: 0.7528 - accuracy: 0.7341 - loss: 0.5685 - val_AUC: 0.8760 - val_Precision: 0.7980 - val_Recall: 0.9758 - val_accuracy: 0.8148 - val_loss: 0.4243 - learning_rate: 0.0010
# Epoch 5/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - AUC: 0.8613 - Precision: 0.8311 - Recall: 0.8633 - accuracy: 0.7761 - loss: 0.4509
# Epoch 5: val_accuracy improved from 0.81476 to 0.85864, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2050s 71s/step - AUC: 0.8614 - Precision: 0.8313 - Recall: 0.8638 - accuracy: 0.7769 - loss: 0.4507 - val_AUC: 0.9239 - val_Precision: 0.9112 - val_Recall: 0.8786 - val_accuracy: 0.8586 - val_loss: 0.3363 - learning_rate: 0.0010
# Epoch 6/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - AUC: 0.8911 - Precision: 0.8564 - Recall: 0.9226 - accuracy: 0.8473 - loss: 0.4056
# Epoch 6: val_accuracy improved from 0.85864 to 0.88214, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4387s 151s/step - AUC: 0.8902 - Precision: 0.8563 - Recall: 0.9210 - accuracy: 0.8463 - loss: 0.4070 - val_AUC: 0.9424 - val_Precision: 0.9028 - val_Recall: 0.9273 - val_accuracy: 0.8821 - val_loss: 0.2826 - learning_rate: 0.0010
# Epoch 7/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - AUC: 0.8481 - Precision: 0.8267 - Recall: 0.8474 - accuracy: 0.7630 - loss: 0.4514
# Epoch 7: val_accuracy improved from 0.88214 to 0.90451, saving model to best_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1455s 50s/step - AUC: 0.8484 - Precision: 0.8269 - Recall: 0.8473 - accuracy: 0.7634 - loss: 0.4510 - val_AUC: 0.9644 - val_Precision: 0.9124 - val_Recall: 0.9516 - val_accuracy: 0.9045 - val_loss: 0.2337 - learning_rate: 0.0010
# Epoch 8/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - AUC: 0.9279 - Precision: 0.9227 - Recall: 0.8580 - accuracy: 0.8557 - loss: 0.3171
# Epoch 8: val_accuracy did not improve from 0.90451
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1181s 41s/step - AUC: 0.9264 - Precision: 0.9207 - Recall: 0.8577 - accuracy: 0.8542 - loss: 0.3201 - val_AUC: 0.9465 - val_Precision: 0.9469 - val_Recall: 0.8393 - val_accuracy: 0.8581 - val_loss: 0.3181 - learning_rate: 0.0010
# Epoch 9/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - AUC: 0.8199 - Precision: 0.8446 - Recall: 0.8140 - accuracy: 0.7546 - loss: 0.5167
# Epoch 9: val_accuracy did not improve from 0.90451
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1201s 41s/step - AUC: 0.8204 - Precision: 0.8444 - Recall: 0.8151 - accuracy: 0.7558 - loss: 0.5164 - val_AUC: 0.9509 - val_Precision: 0.8886 - val_Recall: 0.9489 - val_accuracy: 0.8838 - val_loss: 0.2653 - learning_rate: 0.0010
# Epoch 10/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - AUC: 0.8806 - Precision: 0.8299 - Recall: 0.8435 - accuracy: 0.7745 - loss: 0.4341
# Epoch 10: val_accuracy did not improve from 0.90451
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1192s 41s/step - AUC: 0.8799 - Precision: 0.8310 - Recall: 0.8436 - accuracy: 0.7753 - loss: 0.4346 - val_AUC: 0.9558 - val_Precision: 0.9103 - val_Recall: 0.9383 - val_accuracy: 0.8947 - val_loss: 0.2520 - learning_rate: 1.0000e-04
# Epoch 11/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - AUC: 0.9185 - Precision: 0.9291 - Recall: 0.9417 - accuracy: 0.9097 - loss: 0.2977
# Epoch 11: val_accuracy did not improve from 0.90451
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1300s 45s/step - AUC: 0.9177 - Precision: 0.9268 - Recall: 0.9408 - accuracy: 0.9075 - loss: 0.3004 - val_AUC: 0.9614 - val_Precision: 0.9204 - val_Recall: 0.9372 - val_accuracy: 0.9018 - val_loss: 0.2376 - learning_rate: 1.0000e-04
# Epoch 12/12
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - AUC: 0.8509 - Precision: 0.8404 - Recall: 0.8760 - accuracy: 0.8092 - loss: 0.4446
# Epoch 12: val_accuracy did not improve from 0.90451
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1633s 56s/step - AUC: 0.8520 - Precision: 0.8400 - Recall: 0.8765 - accuracy: 0.8094 - loss: 0.4437 - val_AUC: 0.9617 - val_Precision: 0.9179 - val_Recall: 0.9395 - val_accuracy: 0.9013 - val_loss: 0.2370 - learning_rate: 1.0000e-05

# %%
model.evaluate(train_generator)
# Out:
# 17574/17574 ━━━━━━━━━━━━━━━━━━━━ 7446s 423ms/step - AUC: 0.9632 - Precision: 0.9202 - Recall: 0.9434 - accuracy: 0.9055 - loss: 0.2317
# [0.23337292671203613,
#  0.9627512693405151,
#  0.9181460738182068,
#  0.9438344836235046,
#  0.9041894674301147]

# %%
model.evaluate(validation_generator)
# Out:
# 4393/4393 ━━━━━━━━━━━━━━━━━━━━ 1706s 385ms/step - AUC: 0.9611 - Precision: 0.9188 - Recall: 0.9411 - accuracy: 0.9022 - loss: 0.2358
# [0.23780688643455505,
#  0.9609501361846924,
#  0.9163898825645447,
#  0.9425833225250244,
#  0.9020600914955139]

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img("D:/Download/Plant Diseases Dataset/train/Plant Diseases/0a08af15-adfe-447c-8ed4-17ed2702d810___RS_L.Scorch 0054.JPG",target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=ypred[0]
if a<0.5:
      op="Normal"   
else:
      op="Plant Diceies"
plt.imshow(img)
print("THE UPLOADED X-RAY IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# [[0.999208]]
# THE UPLOADED X-RAY IMAGE IS: Plant Diceies
