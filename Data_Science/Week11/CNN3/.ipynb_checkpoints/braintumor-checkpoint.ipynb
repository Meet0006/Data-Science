# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image

# %%
train_path= 'C:/Users/meetp/Downloads/Brain Tumor Data Set/train'
test_path= 'C:/Users/meetp/Downloads/Brain Tumor Data Set/test'

# %%
train_data= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_data= image.ImageDataGenerator(    
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_data.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 4,
    class_mode = 'binary')
validation_generator = test_data.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 4,
    shuffle=True,
    class_mode = 'binary')
# Out:
# Found 4600 images belonging to 2 classes.
# Found 894 images belonging to 2 classes.

# %%
base_model = tf.keras.applications.EfficientNetB3(weights='imagenet', input_shape=(224,224,3), include_top=False)

for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)          │ ?                           │      10,783,535 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │     0 (unbuilt) │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise_1 (GaussianNoise)     │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,783,535 (41.14 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 10,783,535 (41.14 MB)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

lrp = ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=2)
filepath = 'best_model.keras'  # Change filepath extension to .keras
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks = [checkpoint, lrp]

history = model.fit(
    train_generator,
    epochs=5,
    validation_data=validation_generator,
    steps_per_epoch=5,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# D:\Pycharm_Projects\Data_Science_Internship\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - AUC: 0.5038 - Precision: 0.4543 - Recall: 0.4810 - accuracy: 0.5467 - loss: 0.8968
# Epoch 1: val_accuracy improved from -inf to 0.54922, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 111s 19s/step - AUC: 0.5335 - Precision: 0.4786 - Recall: 0.5119 - accuracy: 0.5639 - loss: 0.8981 - val_AUC: 0.8066 - val_Precision: 0.8333 - val_Recall: 0.0123 - val_accuracy: 0.5492 - val_loss: 0.8911 - learning_rate: 0.0010
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - AUC: 0.7600 - Precision: 0.4869 - Recall: 1.0000 - accuracy: 0.7333 - loss: 1.2331
# Epoch 2: val_accuracy improved from 0.54922 to 0.56711, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 81s 20s/step - AUC: 0.7722 - Precision: 0.4966 - Recall: 1.0000 - accuracy: 0.7361 - loss: 1.1639 - val_AUC: 0.8244 - val_Precision: 0.8571 - val_Recall: 0.0590 - val_accuracy: 0.5671 - val_loss: 0.7880 - learning_rate: 0.0010
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - AUC: 0.8190 - Precision: 0.7750 - Recall: 0.6833 - accuracy: 0.7733 - loss: 0.5767
# Epoch 3: val_accuracy improved from 0.56711 to 0.65884, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 81s 20s/step - AUC: 0.8067 - Precision: 0.7500 - Recall: 0.6736 - accuracy: 0.7611 - loss: 0.6233 - val_AUC: 0.8751 - val_Precision: 0.9322 - val_Recall: 0.2703 - val_accuracy: 0.6588 - val_loss: 0.6164 - learning_rate: 0.0010
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - AUC: 0.9879 - Precision: 0.9818 - Recall: 0.8302 - accuracy: 0.8758 - loss: 0.2944
# Epoch 4: val_accuracy improved from 0.65884 to 0.75951, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 70s 17s/step - AUC: 0.9798 - Precision: 0.9697 - Recall: 0.8433 - accuracy: 0.8799 - loss: 0.3034 - val_AUC: 0.9105 - val_Precision: 0.9138 - val_Recall: 0.5209 - val_accuracy: 0.7595 - val_loss: 0.4746 - learning_rate: 0.0010
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - AUC: 0.8140 - Precision: 0.5117 - Recall: 0.5417 - accuracy: 0.6900 - loss: 0.9533
# Epoch 5: val_accuracy improved from 0.75951 to 0.81544, saving model to best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 17s/step - AUC: 0.8215 - Precision: 0.5306 - Recall: 0.5556 - accuracy: 0.6917 - loss: 0.9094 - val_AUC: 0.9085 - val_Precision: 0.9116 - val_Recall: 0.6585 - val_accuracy: 0.8154 - val_loss: 0.4281 - learning_rate: 0.0010

# %%
model.evaluate(train_generator)
# Out:
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 370s 322ms/step - AUC: 0.8969 - Precision: 0.8415 - Recall: 0.7576 - accuracy: 0.8203 - loss: 0.4106
# [0.4044549763202667,
#  0.8998224139213562,
#  0.8306240439414978,
#  0.7589842081069946,
#  0.8204348087310791]

# %%
model.evaluate(validation_generator)
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 64s 283ms/step - AUC: 0.9207 - Precision: 0.9549 - Recall: 0.6536 - accuracy: 0.8276 - loss: 0.4154
# [0.4259131848812103,
#  0.9114747643470764,
#  0.9238754510879517,
#  0.6560196280479431,
#  0.818791925907135]

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img("C:/Users/meetp/Downloads/brain tumor/h5.jpg",target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=ypred[0]
if a<0.5:
      op="brain tumor"   
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED X-RAY IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# [[0.44727883]]
# THE UPLOADED X-RAY IMAGE IS: brain tumor
